# %%
# Imports here
from __future__ import print_function, division
import numpy as np
import matplotlib.pyplot as plt
from torch.utils import data
import torch
from torch import nn, optim
import torchvision
import torch.nn.functional as F
from torchvision import datasets, transforms, models
from torch.utils.data.sampler import SubsetRandomSampler
from torch.utils.data import Dataset, DataLoader
from skimage import io, transform
from PIL import Image, ImageFile
import json
from torch.optim import lr_scheduler
import seaborn as sns
import cv2
import os
import pandas as pd
from sklearn.metrics import confusion_matrix

# %%
# Load dataset and paths
train_csv = pd.read_csv('/home/gcekcse/Documents/ML_Project_hk/data/train.csv')
test_csv = pd.read_csv('/home/gcekcse/Documents/ML_Project_hk/data/test.csv')
base_dir = "/home/gcekcse/Documents/ML_Project_hk/data"
train_path = base_dir + "/train_images/"
test_path = base_dir + "/test_images/"

# %%
# Check image distribution
counts = train_csv['diagnosis'].value_counts()
class_list = ['No DR', 'Mild', 'Moderate', 'Severe', 'Proliferative']
for i, x in enumerate(class_list):
    counts[x] = counts.pop(i)
plt.figure(figsize=(10, 5))
sns.barplot(x=counts.index, y=counts.values, alpha=0.8, palette='bright')
plt.title('Distribution of Output Classes')
plt.ylabel('Number of Occurrences', fontsize=12)
plt.xlabel('Target Classes', fontsize=12)
plt.show()
# Out:
# /tmp/ipykernel_746687/2314874016.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=counts.index, y=counts.values, alpha=0.8, palette='bright')

# %%
# Dataset class
class CreateDataset(Dataset):
    def __init__(self, df_data, data_dir, transform=None):
        super().__init__()
        self.df = df_data.values
        self.data_dir = data_dir
        self.transform = transform

    def __len__(self):
        return len(self.df)

    def __getitem__(self, index):
        img_name, label = self.df[index]
        img_path = os.path.join(self.data_dir, img_name + '.png')
        image = cv2.imread(img_path)
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)  # Convert to RGB if needed
        if self.transform is not None:
            image = self.transform(image)
        return image, label


# Transforms
train_transforms = transforms.Compose([
    transforms.ToPILImage(),
    transforms.Resize((224, 224)),
    transforms.RandomHorizontalFlip(p=0.4),
    transforms.ToTensor(),
    transforms.Normalize(mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225))
])

test_transforms = transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

# %%
# Dataset loading
train_data = CreateDataset(df_data=train_csv, data_dir=train_path, transform=train_transforms)
test_data = CreateDataset(df_data=test_csv, data_dir=test_path, transform=test_transforms)

# Data loaders
valid_size = 0.2
num_train = len(train_data)
indices = list(range(num_train))
np.random.shuffle(indices)
split = int(np.floor(valid_size * num_train))
train_idx, valid_idx = indices[split:], indices[:split]

train_sampler = SubsetRandomSampler(train_idx)
valid_sampler = SubsetRandomSampler(valid_idx)

trainloader = DataLoader(train_data, batch_size=64, sampler=train_sampler)
validloader = DataLoader(train_data, batch_size=64, sampler=valid_sampler)
testloader = DataLoader(test_data, batch_size=64)

# %%
# ResNet152 Model and fine-tuning
model = models.resnet152(pretrained=True)
num_ftrs = model.fc.in_features
out_ftrs = 5

model.fc = nn.Sequential(
    nn.Linear(num_ftrs, 512),
    nn.ReLU(),
    nn.Linear(512, out_ftrs),
    nn.LogSoftmax(dim=1)
)

# Loss, optimizer, scheduler
criterion = nn.NLLLoss()
optimizer = torch.optim.Adam(filter(lambda p: p.requires_grad, model.parameters()), lr=0.00001)
scheduler = lr_scheduler.StepLR(optimizer, step_size=5, gamma=0.1)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

# Freezing layers
for name, child in model.named_children():
    if name in ['layer2', 'layer3', 'layer4', 'fc']:
        for param in child.parameters():
            param.requires_grad = True
    else:
        for param in child.parameters():
            param.requires_grad = False
# Out:
# /home/gcekcse/hkenv/lib/python3.12/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/gcekcse/hkenv/lib/python3.12/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet152_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet152_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
# Train and test loop
def train_and_test(e):
    epochs = e
    train_losses, test_losses, acc = [], [], []
    valid_loss_min = np.Inf
    model.train()
    print("Model Training started.....")
    
    for epoch in range(epochs):
        running_loss = 0
        batch = 0
        for images, labels in trainloader:
            images, labels = images.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(images)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            running_loss += loss.item()
            batch += 1
            if batch % 10 == 0:
                print(f" epoch {epoch + 1} batch {batch} completed")
        
        test_loss, accuracy = 0, 0
        with torch.no_grad():
            model.eval()
            for images, labels in validloader:
                images, labels = images.to(device), labels.to(device)
                logps = model(images)
                test_loss += criterion(logps, labels)
                ps = torch.exp(logps)
                top_p, top_class = ps.topk(1, dim=1)
                equals = top_class == labels.view(*top_class.shape)
                accuracy += torch.mean(equals.type(torch.FloatTensor))
        
        train_losses.append(running_loss / len(trainloader))
        test_losses.append(test_loss / len(validloader))
        acc.append(accuracy)
        scheduler.step()
        
        print(f"Epoch: {epoch + 1}/{epochs}.. "
              f"Training Loss: {running_loss/len(trainloader):.3f}.. "
              f"Valid Loss: {test_loss/len(validloader):.3f}.. "
              f"Valid Accuracy: {accuracy/len(validloader):.3f}")
        
        if test_loss / len(validloader) <= valid_loss_min:
            torch.save({'model_state_dict': model.state_dict(), 'optimizer_state_dict': optimizer.state_dict()},
                       "/home/gcekcse/Documents/ML_Project_hk/data/models/classifier.pt")
            valid_loss_min = test_loss / len(validloader)
    print('Training Completed Succesfully !')
    return train_losses, test_losses, acc

# %%
train_losses, valid_losses, acc = train_and_test(50)
# Out:
# Model Training started.....
#  epoch 1 batch 10 completed
#  epoch 1 batch 20 completed
#  epoch 1 batch 30 completed
#  epoch 1 batch 40 completed
#  epoch 1 batch 50 completed
#  epoch 1 batch 60 completed
#  epoch 1 batch 70 completed
#  epoch 1 batch 80 completed
#  epoch 1 batch 90 completed
#  epoch 1 batch 100 completed
#  epoch 1 batch 110 completed
#  epoch 1 batch 120 completed
# Epoch: 1/50.. Training Loss: 1.145.. Valid Loss: 0.817.. Valid Accuracy: 0.704
#  epoch 2 batch 10 completed
#  epoch 2 batch 20 completed
#  epoch 2 batch 30 completed
#  epoch 2 batch 40 completed
#  epoch 2 batch 50 completed
#  epoch 2 batch 60 completed
#  epoch 2 batch 70 completed
#  epoch 2 batch 80 completed
#  epoch 2 batch 90 completed
#  epoch 2 batch 100 completed
#  epoch 2 batch 110 completed
#  epoch 2 batch 120 completed
# Epoch: 2/50.. Training Loss: 0.569.. Valid Loss: 0.462.. Valid Accuracy: 0.828
#  epoch 3 batch 10 completed
#  epoch 3 batch 20 completed
#  epoch 3 batch 30 completed
#  epoch 3 batch 40 completed
#  epoch 3 batch 50 completed
#  epoch 3 batch 60 completed
#  epoch 3 batch 70 completed
#  epoch 3 batch 80 completed
#  epoch 3 batch 90 completed
#  epoch 3 batch 100 completed
#  epoch 3 batch 110 completed
#  epoch 3 batch 120 completed
# Epoch: 3/50.. Training Loss: 0.299.. Valid Loss: 0.323.. Valid Accuracy: 0.878
#  epoch 4 batch 10 completed
#  epoch 4 batch 20 completed
#  epoch 4 batch 30 completed
#  epoch 4 batch 40 completed
#  epoch 4 batch 50 completed
#  epoch 4 batch 60 completed
#  epoch 4 batch 70 completed
#  epoch 4 batch 80 completed
#  epoch 4 batch 90 completed
#  epoch 4 batch 100 completed
#  epoch 4 batch 110 completed
#  epoch 4 batch 120 completed
# Epoch: 4/50.. Training Loss: 0.158.. Valid Loss: 0.215.. Valid Accuracy: 0.920
#  epoch 5 batch 10 completed
#  epoch 5 batch 20 completed
#  epoch 5 batch 30 completed
#  epoch 5 batch 40 completed
#  epoch 5 batch 50 completed
#  epoch 5 batch 60 completed
#  epoch 5 batch 70 completed
#  epoch 5 batch 80 completed
#  epoch 5 batch 90 completed
#  epoch 5 batch 100 completed
#  epoch 5 batch 110 completed
#  epoch 5 batch 120 completed
# Epoch: 5/50.. Training Loss: 0.099.. Valid Loss: 0.186.. Valid Accuracy: 0.932
#  epoch 6 batch 10 completed
#  epoch 6 batch 20 completed
#  epoch 6 batch 30 completed
#  epoch 6 batch 40 completed
#  epoch 6 batch 50 completed
#  epoch 6 batch 60 completed
#  epoch 6 batch 70 completed
#  epoch 19 batch 50 completed
#  epoch 19 batch 60 completed
#  epoch 19 batch 70 completed
#  epoch 19 batch 80 completed
#  epoch 19 batch 90 completed
#  epoch 19 batch 100 completed
#  epoch 19 batch 110 completed
#  epoch 19 batch 120 completed
# Epoch: 19/50.. Training Loss: 0.010.. Valid Loss: 0.136.. Valid Accuracy: 0.958
#  epoch 20 batch 10 completed
#  epoch 20 batch 20 completed
#  epoch 20 batch 30 completed
#  epoch 20 batch 40 completed
#  epoch 20 batch 50 completed
#  epoch 20 batch 60 completed
#  epoch 20 batch 70 completed
#  epoch 20 batch 80 completed
#  epoch 20 batch 90 completed
#  epoch 20 batch 100 completed
#  epoch 20 batch 110 completed
#  epoch 20 batch 120 completed
# Epoch: 20/50.. Training Loss: 0.011.. Valid Loss: 0.138.. Valid Accuracy: 0.954
#  epoch 21 batch 10 completed
#  epoch 21 batch 20 completed
#  epoch 21 batch 30 completed
#  epoch 21 batch 40 completed
#  epoch 21 batch 50 completed
#  epoch 21 batch 60 completed
#  epoch 21 batch 70 completed
#  epoch 21 batch 80 completed
#  epoch 21 batch 90 completed
#  epoch 21 batch 100 completed
#  epoch 21 batch 110 completed
#  epoch 21 batch 120 completed
# Epoch: 21/50.. Training Loss: 0.010.. Valid Loss: 0.136.. Valid Accuracy: 0.957
#  epoch 22 batch 10 completed
#  epoch 22 batch 20 completed
#  epoch 22 batch 30 completed
#  epoch 22 batch 40 completed
#  epoch 22 batch 50 completed
#  epoch 22 batch 60 completed
#  epoch 22 batch 70 completed
#  epoch 22 batch 80 completed
#  epoch 22 batch 90 completed
#  epoch 22 batch 100 completed
#  epoch 22 batch 110 completed
#  epoch 22 batch 120 completed
# Epoch: 22/50.. Training Loss: 0.009.. Valid Loss: 0.130.. Valid Accuracy: 0.958
#  epoch 23 batch 10 completed
#  epoch 23 batch 20 completed
#  epoch 23 batch 30 completed
#  epoch 23 batch 40 completed
#  epoch 23 batch 50 completed
#  epoch 23 batch 60 completed
#  epoch 23 batch 70 completed
#  epoch 23 batch 80 completed
#  epoch 23 batch 90 completed
#  epoch 23 batch 100 completed
#  epoch 23 batch 110 completed
#  epoch 23 batch 120 completed
# Epoch: 23/50.. Training Loss: 0.010.. Valid Loss: 0.136.. Valid Accuracy: 0.957
#  epoch 24 batch 10 completed
#  epoch 24 batch 20 completed
#  epoch 24 batch 30 completed
#  epoch 24 batch 40 completed
#  epoch 24 batch 50 completed
#  epoch 24 batch 60 completed
#  epoch 24 batch 70 completed
#  epoch 24 batch 80 completed
#  epoch 24 batch 90 completed
#  epoch 24 batch 100 completed
#  epoch 24 batch 110 completed
#  epoch 24 batch 120 completed
# Epoch: 24/50.. Training Loss: 0.010.. Valid Loss: 0.134.. Valid Accuracy: 0.958
#  epoch 25 batch 10 completed
#  epoch 25 batch 20 completed
#  epoch 25 batch 30 completed
#  epoch 25 batch 40 completed
#  epoch 25 batch 50 completed
#  epoch 25 batch 60 completed
#  epoch 25 batch 70 completed
#  epoch 25 batch 80 completed
#  epoch 25 batch 90 completed
#  epoch 25 batch 100 completed
#  epoch 25 batch 110 completed
#  epoch 25 batch 120 completed
# Epoch: 25/50.. Training Loss: 0.008.. Valid Loss: 0.136.. Valid Accuracy: 0.958
#  epoch 26 batch 10 completed
#  epoch 26 batch 20 completed
#  epoch 26 batch 30 completed
#  epoch 26 batch 40 completed
#  epoch 26 batch 50 completed
#  epoch 26 batch 60 completed
#  epoch 26 batch 70 completed
#  epoch 26 batch 80 completed
#  epoch 26 batch 90 completed
#  epoch 26 batch 100 completed
#  epoch 26 batch 110 completed
#  epoch 26 batch 120 completed
# Epoch: 26/50.. Training Loss: 0.009.. Valid Loss: 0.141.. Valid Accuracy: 0.958
#  epoch 27 batch 10 completed
#  epoch 27 batch 20 completed
#  epoch 27 batch 30 completed
#  epoch 27 batch 40 completed
#  epoch 27 batch 50 completed
#  epoch 27 batch 60 completed
#  epoch 27 batch 70 completed
#  epoch 27 batch 80 completed
#  epoch 27 batch 90 completed
#  epoch 27 batch 100 completed
#  epoch 27 batch 110 completed
#  epoch 27 batch 120 completed
# Epoch: 27/50.. Training Loss: 0.010.. Valid Loss: 0.130.. Valid Accuracy: 0.959
#  epoch 28 batch 10 completed
#  epoch 28 batch 20 completed
#  epoch 28 batch 30 completed
#  epoch 28 batch 40 completed
#  epoch 28 batch 50 completed
#  epoch 28 batch 60 completed
#  epoch 28 batch 70 completed
#  epoch 28 batch 80 completed
#  epoch 28 batch 90 completed
#  epoch 28 batch 100 completed
#  epoch 28 batch 110 completed
#  epoch 28 batch 120 completed
# Epoch: 28/50.. Training Loss: 0.009.. Valid Loss: 0.125.. Valid Accuracy: 0.962
#  epoch 29 batch 10 completed
#  epoch 29 batch 20 completed
#  epoch 29 batch 30 completed
#  epoch 29 batch 40 completed
#  epoch 29 batch 50 completed
#  epoch 29 batch 60 completed
#  epoch 29 batch 70 completed
#  epoch 29 batch 80 completed
#  epoch 29 batch 90 completed
#  epoch 29 batch 100 completed
#  epoch 29 batch 110 completed
#  epoch 29 batch 120 completed
# Epoch: 29/50.. Training Loss: 0.010.. Valid Loss: 0.128.. Valid Accuracy: 0.958
#  epoch 30 batch 10 completed
#  epoch 30 batch 20 completed
#  epoch 30 batch 30 completed
#  epoch 30 batch 40 completed
#  epoch 30 batch 50 completed
#  epoch 30 batch 60 completed
#  epoch 30 batch 70 completed
#  epoch 30 batch 80 completed
#  epoch 30 batch 90 completed
#  epoch 30 batch 100 completed
#  epoch 30 batch 110 completed
#  epoch 30 batch 120 completed
# Epoch: 30/50.. Training Loss: 0.010.. Valid Loss: 0.129.. Valid Accuracy: 0.959
#  epoch 31 batch 10 completed
#  epoch 31 batch 20 completed
#  epoch 31 batch 30 completed
#  epoch 31 batch 40 completed
#  epoch 31 batch 50 completed
#  epoch 31 batch 60 completed
#  epoch 31 batch 70 completed
#  epoch 31 batch 80 completed
#  epoch 31 batch 90 completed
#  epoch 31 batch 100 completed
#  epoch 31 batch 110 completed
#  epoch 31 batch 120 completed
# Epoch: 31/50.. Training Loss: 0.010.. Valid Loss: 0.136.. Valid Accuracy: 0.957
#  epoch 32 batch 10 completed
# Epoch: 44/50.. Training Loss: 0.009.. Valid Loss: 0.134.. Valid Accuracy: 0.959
#  epoch 45 batch 10 completed
#  epoch 45 batch 20 completed
#  epoch 45 batch 30 completed
#  epoch 45 batch 40 completed
#  epoch 45 batch 50 completed
#  epoch 45 batch 60 completed
#  epoch 45 batch 70 completed
#  epoch 45 batch 80 completed
#  epoch 45 batch 90 completed
#  epoch 45 batch 100 completed
#  epoch 45 batch 110 completed
#  epoch 45 batch 120 completed
# Epoch: 45/50.. Training Loss: 0.010.. Valid Loss: 0.132.. Valid Accuracy: 0.959
#  epoch 46 batch 10 completed
#  epoch 46 batch 20 completed
#  epoch 46 batch 30 completed
#  epoch 46 batch 40 completed
#  epoch 46 batch 50 completed
#  epoch 46 batch 60 completed
#  epoch 46 batch 70 completed
#  epoch 46 batch 80 completed
#  epoch 46 batch 90 completed
#  epoch 46 batch 100 completed
#  epoch 46 batch 110 completed
#  epoch 46 batch 120 completed
# Epoch: 46/50.. Training Loss: 0.010.. Valid Loss: 0.145.. Valid Accuracy: 0.957
#  epoch 47 batch 10 completed
#  epoch 47 batch 20 completed
#  epoch 47 batch 30 completed
#  epoch 47 batch 40 completed
#  epoch 47 batch 50 completed
#  epoch 47 batch 60 completed
#  epoch 47 batch 70 completed
#  epoch 47 batch 80 completed
#  epoch 47 batch 90 completed
#  epoch 47 batch 100 completed
#  epoch 47 batch 110 completed
#  epoch 47 batch 120 completed
# Epoch: 47/50.. Training Loss: 0.010.. Valid Loss: 0.146.. Valid Accuracy: 0.956
#  epoch 48 batch 10 completed
#  epoch 48 batch 20 completed
#  epoch 48 batch 30 completed
#  epoch 48 batch 40 completed
#  epoch 48 batch 50 completed
#  epoch 48 batch 60 completed
#  epoch 48 batch 70 completed
#  epoch 48 batch 80 completed
#  epoch 48 batch 90 completed
#  epoch 48 batch 100 completed
#  epoch 48 batch 110 completed
#  epoch 48 batch 120 completed
# Epoch: 48/50.. Training Loss: 0.010.. Valid Loss: 0.146.. Valid Accuracy: 0.955
#  epoch 49 batch 10 completed
#  epoch 49 batch 20 completed
#  epoch 49 batch 30 completed
#  epoch 49 batch 40 completed
#  epoch 49 batch 50 completed
#  epoch 49 batch 60 completed
#  epoch 49 batch 70 completed
#  epoch 49 batch 80 completed
#  epoch 49 batch 90 completed
#  epoch 49 batch 100 completed
#  epoch 49 batch 110 completed
#  epoch 49 batch 120 completed
# Epoch: 49/50.. Training Loss: 0.010.. Valid Loss: 0.141.. Valid Accuracy: 0.960
#  epoch 50 batch 10 completed
#  epoch 50 batch 20 completed
#  epoch 50 batch 30 completed
#  epoch 50 batch 40 completed
#  epoch 50 batch 50 completed
#  epoch 50 batch 60 completed
#  epoch 50 batch 70 completed
#  epoch 50 batch 80 completed
#  epoch 50 batch 90 completed
#  epoch 50 batch 100 completed
#  epoch 50 batch 110 completed
#  epoch 50 batch 120 completed
# Epoch: 50/50.. Training Loss: 0.009.. Valid Loss: 0.134.. Valid Accuracy: 0.961
# Training Completed Succesfully !

# %%
# Plotting training curves
plt.plot(train_losses, label='train_loss')
plt.plot([x.cpu().numpy() for x in valid_losses], label='valid_loss')
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend(frameon=False)
plt.show()

plt.plot([x.cpu().numpy() for x in acc], label='accuracy')
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend(frameon=False)
plt.show()

# %%
# Generate Confusion Matrix
def generate_confusion_matrix(model, dataloader):
    y_true, y_pred = [], []
    with torch.no_grad():
        model.eval()
        for images, labels in dataloader:
            images, labels = images.to(device), labels.to(device)
            logps = model(images)
            ps = torch.exp(logps)
            top_p, top_class = ps.topk(1, dim=1)
            y_true.extend(labels.cpu().numpy())
            y_pred.extend(top_class.cpu().numpy())
    
    cm = confusion_matrix(y_true, [x[0] for x in y_pred])
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_list, yticklabels=class_list)
    plt.title('Confusion Matrix')
    plt.xlabel('Predicted Label')
    plt.ylabel('True Label')
    plt.show()

# %%
# Generate confusion matrix for the validation set
generate_confusion_matrix(model, validloader)

# %%
from sklearn.metrics import classification_report

# %%
# Redefine the ResNet152 model architecture
model = models.resnet152(pretrained=False)  # Ensure 'pretrained=False' since you're loading your own weights
num_ftrs = model.fc.in_features
out_ftrs = 5  # Adjust to your number of output classes

# Modify the fully connected layer to match the output classes (5 in your case)
model.fc = nn.Sequential(
    nn.Linear(num_ftrs, 512),
    nn.ReLU(),
    nn.Linear(512, out_ftrs),
    nn.LogSoftmax(dim=1)
)

# Load the saved model state
checkpoint = torch.load("/home/gcekcse/Documents/ML_Project_hk/data/models/classifier_ResNett152.pt")
model.load_state_dict(checkpoint['model_state_dict'])
model.eval()  # Set model to evaluation mode

# Generate classification report
def generate_classification_report(model, dataloader):
    y_true, y_pred = [], []
    with torch.no_grad():
        model.eval()
        for images, labels in dataloader:
            images, labels = images.to(device), labels.to(device)
            logps = model(images)
            ps = torch.exp(logps)
            top_p, top_class = ps.topk(1, dim=1)
            y_true.extend(labels.cpu().numpy())
            y_pred.extend(top_class.cpu().numpy())

    # Print classification report
    print(classification_report(y_true, [x[0] for x in y_pred], target_names=class_list))

# Generate classification report for the validation set
generate_classification_report(model, validloader)
# Out:
# /home/gcekcse/hkenv/lib/python3.12/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# /tmp/ipykernel_746687/3848671346.py:15: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load("/home/gcekcse/Documents/ML_Project_hk/data/models/classifier_ResNett152.pt")
#                precision    recall  f1-score   support
#
#         No DR       1.00      1.00      1.00       409
#          Mild       0.99      0.99      0.99       391
#      Moderate       0.99      0.96      0.97       413
#        Severe       0.98      0.99      0.99       402
# Proliferative       0.97      0.98      0.98       385
#
#      accuracy                           0.99      2000
#     macro avg       0.99      0.99      0.99      2000
#  weighted avg       0.99      0.99      0.99      2000

# %%
import torch
from torchvision import transforms
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# Define the class names (update if necessary)
class_list = ['No DR', 'Mild', 'Moderate', 'Severe', 'Proliferative']

# Define the transformations (the same used during training)
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

# Function to classify an input image
def classify_image(image_path, model):
    # Load the image
    image = Image.open(image_path).convert("RGB")  # Ensure the image is in RGB mode
    image_tensor = transform(image)  # Apply transformations

    # Add batch dimension
    image_tensor = image_tensor.unsqueeze(0).to(device)

    # Set the model to evaluation mode
    model.eval()

    with torch.no_grad():
        # Forward pass
        logps = model(image_tensor)
        ps = torch.exp(logps)  # Get probabilities
        top_p, top_class = ps.topk(1, dim=1)  # Get the top class

    # Get the predicted class and probability
    predicted_class = class_list[top_class.cpu().numpy()[0][0]]
    predicted_probability = top_p.cpu().numpy()[0][0]

    return predicted_class, predicted_probability, image

# Example usage
image_paths = [
    "/home/gcekcse/Documents/ML_Project_hk/data/my_images/1.jpeg",
    "/home/gcekcse/Documents/ML_Project_hk/data/my_images/2.jpeg",
    "/home/gcekcse/Documents/ML_Project_hk/data/my_images/3.jpeg"
]

# Loop through each image
for image_path in image_paths:
    predicted_class, predicted_probability, image = classify_image(image_path, model)
    
    # Display the image and the prediction
    plt.imshow(image)
    plt.title(f'Predicted Class: {predicted_class}\nProbability: {predicted_probability:.4f}')
    plt.axis('off')  # Hide axes
    plt.show()
